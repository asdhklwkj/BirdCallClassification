# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read
from IPython.lib.display import Audio
from scipy.fftpack import fft, ifft
from scipy.io import loadmat
import scipy.signal as sgnl
import scipy.io.wavfile as wav
import pyaudio
import sys
import wave
import operator
import scipy
from python_speech_features import mfcc

# %%
import scipy.io.wavfile as wav
import scipy.signal as sgnl
from python_speech_features import mfcc
import os

filter_data = loadmat('highpass(500).mat') # load the filter obtained from␣
Coeffs = filter_data['ba'].astype(np.float64) # getting filter coefficients
b = Coeffs[0,:] # first column is b
a = 1 # fir filter
# New base path reflecting the provided directory structure
base_path = r"C:\Users\hongj\OneDrive\바탕 화면\마지막\Kendall's Tau\SAMPLES(UPDATED_Categorised)"

# Define filter coefficients (b, a), assuming they are defined elsewhere in your code
# b, a = ...


# Function to read all WAV files in a given species folder and process them
def process_wav_files(species_folder, variable_letter):
    species_path = os.path.join(base_path, species_folder)
    wav_files = [f for f in os.listdir(species_path) if f.endswith('.wav')]
    
    for wav_file in wav_files:
        # Extracting the sequence number from the file name
        sequence_number = wav_file.split('_')[-1].split('.')[0]
        raw_variable_name = f"{variable_letter}{sequence_number}"
        filtered_variable_name = f"{variable_letter}{sequence_number}_"
        mfcc_variable_name = f"mfcc_{variable_letter}{sequence_number}"
        
        full_path = os.path.join(species_path, wav_file)
        
        try:
            Fs, audio_data = wav.read(full_path)
            # Store raw audio data in global variable
            globals()[raw_variable_name] = audio_data
            
            # Filter the audio data and store it in a new global variable
            filtered_audio = sgnl.lfilter(b, a, audio_data)
            globals()[filtered_variable_name] = filtered_audio
            
            # Calculate the MFCC of the filtered audio and store it in another new global variable
            mfcc_data = mfcc(filtered_audio, Fs)
            globals()[mfcc_variable_name] = mfcc_data
            
        except IOError as e:
            print(f"Could not process file {full_path}: {e}")

# Process WAV files for Long-tailed Duck
process_wav_files("Long_tailed_Duck_Clangula_hyemalis", "a")

# Process WAV files for Velvet Scoter
process_wav_files("Velvet_Scoter_Melanitta_fusca", "b")

process_wav_files("Aquatic_Warbler_Acrocephalus_paludicola", "c")

process_wav_files("Atlantic_Puffin_Fratercula_arctica", "d")

process_wav_files("Balearic_Shearwater_Puffinus_mauretanicus", "e")

process_wav_files("Black_legged_Kittiwake_Rissa_tridactyla", "f")

process_wav_files("Great_Bustard_Otis_tarda", "g")

process_wav_files("Horned_Grebe_Podiceps_auritus", "h")

process_wav_files("Leach's_Storm_Petrel_Hydrobates_leucorhous", "i")

process_wav_files("European_Turtle_Dove_Streptopelia_turtur", "j")

# %%
mfcc_b8
# Out:
# array([[ 11.12821956, -21.08808878, -25.36465129, ...,   2.43903787,
#          -2.00225945,  -8.52928947],
#        [ 11.49944985, -24.00365751, -35.82858401, ...,  -9.42436161,
#           1.40614995,  -7.25205275],
#        [ 11.4673077 , -21.82353328, -34.24661994, ...,  -9.74742208,
#           5.40896984,  -6.06449914],
#        ...,
#        [ 13.76172876, -17.3185092 , -47.14131774, ...,   0.8673242 ,
#           5.63156937,  -4.99101737],
#        [ 13.86034152,  -9.65115963, -38.01260746, ...,  -1.01584462,
#           0.06813688,  -4.05376225],
#        [ 13.70770902,  -9.51508434, -41.25079942, ...,  -4.69995413,
#           0.62061713,  -5.11128852]])

# %%
Fs, input_audio_Pure = wav.read("Atlantic_Puffin_2_TEST.wav")
#read to created file as input
#handling input_audio
display(Audio(input_audio_Pure, rate=Fs))#pure audio file
print('Original audio input :')

# Fourier transform of not-filtered input audio
N = 48000
w = np.linspace(-np.pi, np.pi, N)
input_fourier_noisy = np.fft.fftshift(np.fft.fft(input_audio_Pure, N))
frequency_kHz = Fs/(2*np.pi)*w/1000  # Convert w to kHz
plt.plot(frequency_kHz, np.real(input_fourier_noisy))
plt.title("Fourier Transform of Original Audio")
plt.xlabel("Frequency (kHz)")
plt.ylabel("Magnitude")
plt.show()


#lowpass, equiripple, 0.2pi cutoff frequency  filter, 
#designed for the denoising audio, designed on pyfda
filter_data = loadmat('highpass(500).mat') # load the filter obtained from␣
Coeffs = filter_data['ba'].astype(np.float64) # getting filter coefficients
b = Coeffs[0,:] # first column is b
a = 1 # fir filter

w, Hw = sgnl.freqz(b,a)

input_audio = sgnl.lfilter(b, a, input_audio_Pure) #filtering via convolution

display(Audio(input_audio, rate=Fs))
print("Filtered audio input :")

# Fourier transform of filtered input audio
w = np.linspace(-np.pi, np.pi, N)
input_fourier = np.fft.fftshift(np.fft.fft(input_audio, N))
frequency_kHz = Fs/(2*np.pi)*w/1000  # Convert w to kHz
plt.plot(frequency_kHz, np.real(input_fourier))
plt.title("Fourier Transform of Filtered Audio")
plt.xlabel("Frequency (kHz)")
plt.ylabel("Magnitude")
plt.show()

mfcc_input = mfcc(input_audio, Fs, numcep=13)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Original audio input :
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Filtered audio input :

# %%
# low pass filter
w, Hw = sgnl.freqz(b,a)

Hw_mag = abs(Hw)
Hw_phs = np.unwrap(np.angle(Hw))

plt.figure(figsize=[10,3])
plt.plot(w/np.pi, Hw_mag)
plt.title("Magnitude Spectrum")
plt.ylabel('degrees')
plt.xlabel("w (xpi)")
plt.show()

plt.figure(figsize=[10,3])
plt.plot(w/np.pi, Hw_phs), 
plt.ylabel('degrees')
plt.title("Phase spectrum")
plt.xlabel("w (xpi)")
plt.show()




##fourier
N = 48000

# Downsample the audio data
downsample_factor = 4
a1_downsampled = a2_[::downsample_factor]
N_downsampled = len(a1_downsampled)

# %%
import scipy.stats
import re

# Function to compute Kendall's Tau for all MFCCs of a species
def compute_kendall_tau(mfcc_input, species_prefix):
    similarity_scores = []
    # Create a static list of global variable names to iterate over
    global_vars = list(globals().keys())
    
    # Use regular expression to find all corresponding mfcc variables
    pattern = re.compile(f"^mfcc_{species_prefix}\\d+$")
    for var_name in global_vars:
        if pattern.match(var_name):
            mfcc_data = globals()[var_name]
            if mfcc_data is not None:
                similarity_score = scipy.stats.kendalltau(mfcc_input, mfcc_data)
                similarity_var_name = f"similarity_{var_name[5:]}"  # removes 'mfcc_' prefix
                globals()[similarity_var_name] = similarity_score
                print(f"{similarity_var_name}: {similarity_score}")
                if similarity_score.correlation is not None:  # Ensure the correlation is not None before appending
                    similarity_scores.append(similarity_score.correlation)
    return similarity_scores


# Assuming mfcc_input is defined
# mfcc_input = ...

# Compute Kendall's Tau for Long-tailed Duck and store the mean correlation
similarity_to_Long_tailed_Duck = compute_kendall_tau(mfcc_input, 'a')
mean_Long_tailed_Duck = sum(similarity_to_Long_tailed_Duck) / len(similarity_to_Long_tailed_Duck) if similarity_to_Long_tailed_Duck else 0

# Compute Kendall's Tau for Velvet Scoter and store the mean correlation
similarity_to_Velvet_Scoter = compute_kendall_tau(mfcc_input, 'b')
mean_Velvet_Scoter = sum(similarity_to_Velvet_Scoter) / len(similarity_to_Velvet_Scoter) if similarity_to_Velvet_Scoter else 0

similarity_to_Aquatic_Warbler = compute_kendall_tau(mfcc_input, 'c')
mean_Aquatic_Warbler = sum(similarity_to_Aquatic_Warbler) / len(similarity_to_Aquatic_Warbler) if similarity_to_Aquatic_Warbler else 0

similarity_to_Atlantic_Puffin = compute_kendall_tau(mfcc_input, 'd')
mean_Atlantic_Puffin = sum(similarity_to_Atlantic_Puffin) / len(similarity_to_Atlantic_Puffin) if similarity_to_Atlantic_Puffin else 0

similarity_to_Balearic_Shearwater = compute_kendall_tau(mfcc_input, 'e')
mean_Balearic_Shearwater = sum(similarity_to_Balearic_Shearwater) / len(similarity_to_Balearic_Shearwater) if similarity_to_Balearic_Shearwater else 0

similarity_to_Black_legged_Kittiwake = compute_kendall_tau(mfcc_input, 'f')
mean_Black_legged_Kittiwake = sum(similarity_to_Black_legged_Kittiwake) / len(similarity_to_Black_legged_Kittiwake) if similarity_to_Black_legged_Kittiwake else 0

similarity_to_Great_Bustard = compute_kendall_tau(mfcc_input, 'g')
mean_Great_Bustard = sum(similarity_to_Great_Bustard) / len(similarity_to_Great_Bustard) if similarity_to_Great_Bustard else 0

similarity_to_Horned_Grebe = compute_kendall_tau(mfcc_input, 'h')
mean_Horned_Grebe = sum(similarity_to_Horned_Grebe) / len(similarity_to_Horned_Grebe) if similarity_to_Horned_Grebe else 0

similarity_to_Leachs_Storm_Petrel = compute_kendall_tau(mfcc_input, 'i')
mean_Leachs_Storm_Petrel = sum(similarity_to_Leachs_Storm_Petrel) / len(similarity_to_Leachs_Storm_Petrel) if similarity_to_Leachs_Storm_Petrel else 0

similarity_to_European_Turtle_Dove = compute_kendall_tau(mfcc_input, 'j')
mean_European_Turtle_Dove = sum(similarity_to_European_Turtle_Dove) / len(similarity_to_European_Turtle_Dove) if similarity_to_European_Turtle_Dove else 0


# Hashmap to store the mean correlation values
sum_dictionary = {
    "Long_tailed_Duck_Clangula_hyemalis": mean_Long_tailed_Duck,
    "Velvet_Scoter_Melanitta_fusca": mean_Velvet_Scoter,
    "Aquatic_Warbler_Acrocephalus_paludicola": mean_Aquatic_Warbler,
    "Atlantic_Puffin_Fratercula_arctica": mean_Atlantic_Puffin,
    "Balearic_Shearwater_Puffinus_mauretanicus": mean_Balearic_Shearwater,
    "Black_legged_Kittiwake_Rissa_tridactyla": mean_Black_legged_Kittiwake,
    "Great_Bustard_Otis_tarda": mean_Great_Bustard,
    "Horned_Grebe_Podiceps_auritus": mean_Horned_Grebe,
    "Leach's_Storm_Petrel_Hydrobates_leucorhous": mean_Leachs_Storm_Petrel,
    "European_Turtle_Dove_Streptopelia_turtur": mean_European_Turtle_Dove
    # Add other species and their mean correlation values here
}

# Print cumulative correlations
print("\nCumulative Correlations")
for species, mean_correlation in sum_dictionary.items():
    print(f"{species}: {mean_correlation}")

# Find and print the owner of the audio based on the highest mean correlation
owner_of_audio = max(sum_dictionary, key=sum_dictionary.get)
print("\nOwner of the audio:", owner_of_audio)
# Out:
# similarity_a1: KendalltauResult(correlation=0.1670645292032073, pvalue=5.6094006151965036e-55)
# similarity_a10: KendalltauResult(correlation=0.18048615010696542, pvalue=7.324655320626956e-64)
# similarity_a100: KendalltauResult(correlation=0.08822025603326872, pvalue=1.6312931197781333e-16)
# similarity_a101: KendalltauResult(correlation=0.05809181428891667, pvalue=5.628243487287396e-08)
# similarity_a102: KendalltauResult(correlation=0.1782262185166359, pvalue=2.560843748780441e-62)
# similarity_a103: KendalltauResult(correlation=0.2087104023718954, pvalue=9.108970424408047e-85)
# similarity_a104: KendalltauResult(correlation=0.32313724794407533, pvalue=1.9887661262390178e-200)
# similarity_a105: KendalltauResult(correlation=0.25617849911042007, pvalue=1.0000861899123848e-126)
# similarity_a11: KendalltauResult(correlation=0.19637187500041378, pvalue=2.946127308560888e-75)
# similarity_a113: KendalltauResult(correlation=0.16664347328234674, pvalue=1.0389811103755724e-54)
# similarity_a114: KendalltauResult(correlation=0.17003337066784105, pvalue=6.956984897871724e-57)
# similarity_a115: KendalltauResult(correlation=0.1655328389854353, pvalue=5.241934150102701e-54)
# similarity_a119: KendalltauResult(correlation=0.18801219367354213, pvalue=3.8460912659289756e-69)
# similarity_a12: KendalltauResult(correlation=0.1876231803730741, pvalue=7.297531670894618e-69)
# similarity_a120: KendalltauResult(correlation=0.1459322886468097, pvalue=2.2759915333777912e-42)
# similarity_a121: KendalltauResult(correlation=0.1767877431945513, pvalue=2.4034923758192604e-61)
# similarity_a126: KendalltauResult(correlation=0.1646348511693107, pvalue=1.9248197126672406e-53)
# similarity_a13: KendalltauResult(correlation=0.20859970968326666, pvalue=1.1151819487150718e-84)
# similarity_a14: KendalltauResult(correlation=0.21386741054978123, pvalue=6.516635858822645e-89)
# similarity_a15: KendalltauResult(correlation=0.17206609094993264, pvalue=3.295013770331432e-58)
# similarity_a16: KendalltauResult(correlation=0.24941697657750656, pvalue=3.148311989016221e-120)
# similarity_a17: KendalltauResult(correlation=0.183681673249748, pvalue=4.458535835739015e-66)
# similarity_a18: KendalltauResult(correlation=0.2497003286751926, pvalue=1.695289841321015e-120)
# similarity_a19: KendalltauResult(correlation=0.31491527044037815, pvalue=1.8350510215928754e-190)
# similarity_a2: KendalltauResult(correlation=0.2417582606736021, pvalue=4.458426123509042e-113)
# similarity_a20: KendalltauResult(correlation=0.3393010286343184, pvalue=9.139778513848162e-221)
# similarity_a21: KendalltauResult(correlation=0.33153665152763195, pvalue=7.142830953770585e-211)
# similarity_a22: KendalltauResult(correlation=0.2598697560166309, pvalue=2.3962880853461517e-130)
# similarity_a23: KendalltauResult(correlation=0.21977199159847793, pvalue=8.790649711102999e-94)
# similarity_a24: KendalltauResult(correlation=0.23722065488495708, pvalue=6.042747813487518e-109)
# similarity_a25: KendalltauResult(correlation=0.2438428847044287, pvalue=5.305550321814933e-115)
# similarity_a26: KendalltauResult(correlation=0.22800350244377945, pvalue=8.600669924396844e-101)
# similarity_a27: KendalltauResult(correlation=0.37625941069913693, pvalue=5.462400000171656e-271)
# similarity_a28: KendalltauResult(correlation=0.3309794806738643, pvalue=3.5892019049845655e-210)
# similarity_a29: KendalltauResult(correlation=0.24647541106246315, pvalue=1.8661991834906955e-117)
# similarity_a30: KendalltauResult(correlation=0.20436928934631865, pvalue=2.3497813917840277e-81)
# similarity_a31: KendalltauResult(correlation=0.2229982332864302, pvalue=1.6877444267037204e-96)
# similarity_a32: KendalltauResult(correlation=0.24334450279055475, pvalue=1.5357344033802852e-114)
# similarity_a33: KendalltauResult(correlation=0.2226619181798309, pvalue=3.253469333179878e-96)
# similarity_a34: KendalltauResult(correlation=0.2785961518931429, pvalue=1.647656703573368e-149)
# similarity_a35: KendalltauResult(correlation=0.2251323777305907, pvalue=2.561862090314403e-98)
# similarity_a36: KendalltauResult(correlation=0.24035368167722201, pvalue=8.640885270135879e-112)
# similarity_a37: KendalltauResult(correlation=0.25123254852305366, pvalue=5.891999333309605e-122)
# similarity_a38: KendalltauResult(correlation=0.29544712762403574, pvalue=6.87796086152537e-168)
# similarity_a39: KendalltauResult(correlation=0.2961645115797661, pvalue=1.074300456899158e-168)
# similarity_a4: KendalltauResult(correlation=0.17807103690051998, pvalue=3.26338114960355e-62)
# similarity_a40: KendalltauResult(correlation=0.2988905176485324, pvalue=8.898747519633406e-172)
# similarity_a41: KendalltauResult(correlation=0.3199112710711676, pvalue=1.7339034956075132e-196)
# similarity_a42: KendalltauResult(correlation=0.2884636900837756, pvalue=3.8448928531971724e-160)
# similarity_a43: KendalltauResult(correlation=0.28859159575030113, pvalue=2.7838590588354124e-160)
# similarity_a44: KendalltauResult(correlation=0.33748916409939517, pvalue=1.9496436662656626e-218)
# similarity_a45: KendalltauResult(correlation=0.3077011789963007, pvalue=6.253211026686965e-182)
# similarity_a46: KendalltauResult(correlation=0.23537913106504244, pvalue=2.728508676565251e-107)
# similarity_a47: KendalltauResult(correlation=0.23671115073921137, pvalue=1.7391284576378795e-108)
# similarity_a48: KendalltauResult(correlation=0.20834813539092858, pvalue=1.76560046424784e-84)
# similarity_a49: KendalltauResult(correlation=0.3193842891324805, pvalue=7.567811369729435e-196)
# similarity_a5: KendalltauResult(correlation=0.3299443186646543, pvalue=7.153049310295651e-209)
# similarity_a50: KendalltauResult(correlation=0.268801437839766, pvalue=2.5439201539846774e-139)
# similarity_a51: KendalltauResult(correlation=0.30630057222558904, pvalue=2.690307167465852e-180)
# similarity_a52: KendalltauResult(correlation=0.26543007750739134, pvalue=6.7353727269876146e-136)
# similarity_a53: KendalltauResult(correlation=0.21328111004111122, pvalue=1.9516022786713026e-88)
# similarity_a54: KendalltauResult(correlation=0.20548813290961163, pvalue=3.151971820785639e-82)
# similarity_a55: KendalltauResult(correlation=0.1568786833290058, pvalue=1.0883118001881256e-48)
# similarity_a56: KendalltauResult(correlation=0.1793471806002854, pvalue=4.4172194816285703e-63)
# similarity_a57: KendalltauResult(correlation=0.1827354890955123, pvalue=2.038202909211636e-65)
# similarity_a58: KendalltauResult(correlation=0.16046295495721186, pvalue=7.393434568224449e-51)
# similarity_a59: KendalltauResult(correlation=0.21455857781609947, pvalue=1.7814777744605688e-89)
# similarity_a6: KendalltauResult(correlation=0.2524001180545469, pvalue=4.4929497729466575e-123)
# similarity_a60: KendalltauResult(correlation=0.1705050062622138, pvalue=3.4394175418483805e-57)
# similarity_a61: KendalltauResult(correlation=0.16258121049869836, pvalue=3.671327039236353e-52)
# similarity_a62: KendalltauResult(correlation=0.2960932763327777, pvalue=1.292054523819878e-168)
# similarity_a63: KendalltauResult(correlation=0.18468876486423397, pvalue=8.768558744422059e-67)
# similarity_a64: KendalltauResult(correlation=0.17028547459026824, pvalue=4.775218591153787e-57)
# similarity_a65: KendalltauResult(correlation=0.14261865799415052, pvalue=1.5179118230552244e-40)
# similarity_a66: KendalltauResult(correlation=0.13837499690497418, pvalue=2.862623794542148e-38)
# similarity_a67: KendalltauResult(correlation=0.1517677529688746, pvalue=1.1068924288795437e-45)
# similarity_a68: KendalltauResult(correlation=0.21902177057722133, pvalue=3.7162993332414524e-93)
# similarity_a69: KendalltauResult(correlation=0.15933563731249276, pvalue=3.596864147075976e-50)
# similarity_a7: KendalltauResult(correlation=0.23738086798691974, pvalue=4.33180212494908e-109)
# similarity_a70: KendalltauResult(correlation=0.16887639373813051, pvalue=3.8846926011792605e-56)
# similarity_a71: KendalltauResult(correlation=0.21976987307812137, pvalue=8.826569913032422e-94)
# similarity_a73: KendalltauResult(correlation=0.28853519014580853, pvalue=3.2099519449262925e-160)
# similarity_a75: KendalltauResult(correlation=0.3228255606366207, pvalue=4.797585487948007e-200)
# similarity_a77: KendalltauResult(correlation=0.32523670161739765, pvalue=5.163789568429049e-203)
# similarity_a8: KendalltauResult(correlation=0.2547572367662323, pvalue=2.400446056794838e-125)
# similarity_a80: KendalltauResult(correlation=0.3349495878220035, pvalue=3.4154521903677045e-215)
# similarity_a81: KendalltauResult(correlation=0.34261730743742325, pvalue=4.633031229286613e-225)
# similarity_a82: KendalltauResult(correlation=0.2965720619333537, pvalue=3.733993756557205e-169)
# similarity_a84: KendalltauResult(correlation=0.3506139273381944, pvalue=1.3727090006072844e-235)
# similarity_a85: KendalltauResult(correlation=0.1815334936082255, pvalue=1.389546052417775e-64)
# similarity_a86: KendalltauResult(correlation=0.2530820167943053, pvalue=9.939199888482451e-124)
# similarity_a87: KendalltauResult(correlation=0.3436797453962236, pvalue=1.9099980493089442e-226)
# similarity_a88: KendalltauResult(correlation=0.3522049361259492, pvalue=1.0326494847719659e-237)
# similarity_a89: KendalltauResult(correlation=0.3017192719545906, pvalue=5.267410956451505e-175)
# similarity_a9: KendalltauResult(correlation=0.18611082165355547, pvalue=8.6920072307122e-68)
# similarity_a90: KendalltauResult(correlation=0.33783845514317823, pvalue=6.949210404112196e-219)
# similarity_a91: KendalltauResult(correlation=0.26882527119377697, pvalue=2.4052087346713637e-139)
# similarity_a92: KendalltauResult(correlation=0.082208785212622, pvalue=1.534756737440804e-14)
# similarity_a93: KendalltauResult(correlation=0.05183529404599123, pvalue=1.2636414988716855e-06)
# similarity_a94: KendalltauResult(correlation=0.031743776614739524, pvalue=0.003004264823726393)
# similarity_a95: KendalltauResult(correlation=0.025449917450530234, pvalue=0.017360972176017526)
# similarity_a96: KendalltauResult(correlation=0.040242221024963984, pvalue=0.00016875757610604206)
# similarity_a97: KendalltauResult(correlation=0.09957456139015189, pvalue=1.3039169747313105e-20)
# similarity_a98: KendalltauResult(correlation=0.036201937890014635, pvalue=0.0007142887202828448)
# similarity_a99: KendalltauResult(correlation=0.10409866161152402, pvalue=2.2285121106050733e-22)
# similarity_b1: KendalltauResult(correlation=0.23066701216202817, pvalue=4.087887819976391e-103)
# similarity_b10: KendalltauResult(correlation=0.15533957828998599, pvalue=8.969522587601912e-48)
# similarity_b11: KendalltauResult(correlation=0.273678006885456, pvalue=2.389169735210849e-144)
# similarity_b13: KendalltauResult(correlation=0.18007568678788752, pvalue=1.4014590150111905e-63)
# similarity_b15: KendalltauResult(correlation=0.24398985705416304, pvalue=3.8764094096013203e-115)
# similarity_b16: KendalltauResult(correlation=0.24581999382716135, pvalue=7.661700300243646e-117)
# similarity_b17: KendalltauResult(correlation=0.18121836370519148, pvalue=2.2936249092033222e-64)
# similarity_b18: KendalltauResult(correlation=0.1529792817977658, pvalue=2.1884892126957386e-46)
# similarity_b20: KendalltauResult(correlation=0.2097045180491976, pvalue=1.472938544668459e-85)
# similarity_b21: KendalltauResult(correlation=0.17860702255072236, pvalue=1.411355359527847e-62)
# similarity_b24: KendalltauResult(correlation=0.20841169100162454, pvalue=1.5721835581735352e-84)
# similarity_b26: KendalltauResult(correlation=0.22411681203467862, pvalue=1.8888050897439344e-97)
# similarity_b27: KendalltauResult(correlation=0.24733394143694734, pvalue=2.9177452125615352e-118)
# similarity_b3: KendalltauResult(correlation=0.07347359615255519, pvalue=6.507900468934477e-12)
# similarity_b301: KendalltauResult(correlation=0.20874085610202056, pvalue=8.615582093393461e-85)
# similarity_b302: KendalltauResult(correlation=0.27092843227772323, pvalue=1.6744177693517628e-141)
# similarity_b303: KendalltauResult(correlation=0.17571762559945853, pvalue=1.256621140343172e-60)
# similarity_b304: KendalltauResult(correlation=0.25862989197797115, pvalue=3.993861612890086e-129)
# similarity_b305: KendalltauResult(correlation=0.2465087777580785, pvalue=1.7365548474923935e-117)
# similarity_b306: KendalltauResult(correlation=0.2731891583131864, pvalue=7.695993729670499e-144)
# similarity_b5: KendalltauResult(correlation=0.2642053079262718, pvalue=1.1512665583376055e-134)
# similarity_b7: KendalltauResult(correlation=0.19691170941611938, pvalue=1.1626159043247878e-75)
# similarity_b8: KendalltauResult(correlation=0.18600674934104086, pvalue=1.030012615027765e-67)
# similarity_c1: KendalltauResult(correlation=0.30712308775401226, pvalue=2.960074440069375e-181)
# similarity_c10: KendalltauResult(correlation=0.27957596755803854, pvalue=1.5053720035333065e-150)
# similarity_c101: KendalltauResult(correlation=0.2751291933296798, pvalue=7.3252366122082965e-146)
# similarity_c103: KendalltauResult(correlation=0.26256160094464825, pvalue=5.0903500771684925e-133)
# similarity_c105: KendalltauResult(correlation=0.26778852029429956, pvalue=2.744220260700095e-138)
# similarity_c106: KendalltauResult(correlation=0.34591001770156166, pvalue=2.291232489654711e-229)
# similarity_c11: KendalltauResult(correlation=0.3509121090783761, pvalue=5.49928458326674e-236)
# similarity_c110: KendalltauResult(correlation=0.2703185632300868, pvalue=7.098294776147141e-141)
# similarity_c111: KendalltauResult(correlation=0.2786634149144628, pvalue=1.3984333653122798e-149)
# similarity_c112: KendalltauResult(correlation=0.3294917497534903, pvalue=2.638448309492424e-208)
# similarity_c113: KendalltauResult(correlation=0.3367018689718993, pvalue=1.9864921071644573e-217)
# similarity_c114: KendalltauResult(correlation=0.30639564082658843, pvalue=2.085196363182015e-180)
# similarity_c116: KendalltauResult(correlation=0.32450634172448356, pvalue=4.114811729490507e-202)
# similarity_c117: KendalltauResult(correlation=0.2729399673562495, pvalue=1.395978448068843e-143)
# similarity_c118: KendalltauResult(correlation=0.2985338117835016, pvalue=2.2604377162782456e-171)
# similarity_c119: KendalltauResult(correlation=0.3349122489007197, pvalue=3.810257319946598e-215)
# similarity_c120: KendalltauResult(correlation=0.29626249314625563, pvalue=8.333815075670051e-169)
# similarity_c121: KendalltauResult(correlation=0.29908648078151157, pvalue=5.329716649545749e-172)
# similarity_c122: KendalltauResult(correlation=0.31065969267419635, pvalue=2.0930831587292756e-185)
# similarity_c124: KendalltauResult(correlation=0.26647053581749264, pvalue=5.978669022144963e-137)
# similarity_c125: KendalltauResult(correlation=0.27943720447468573, pvalue=2.1136904486945338e-150)
# similarity_c126: KendalltauResult(correlation=0.32204197291974873, pvalue=4.373759279398142e-199)
# similarity_c128: KendalltauResult(correlation=0.3514073132117153, pvalue=1.2016916758030127e-236)
# similarity_c129: KendalltauResult(correlation=0.3445459554070002, pvalue=1.4086616974462242e-227)
# similarity_c130: KendalltauResult(correlation=0.34687394446378333, pvalue=1.2353445420172436e-230)
# similarity_c131: KendalltauResult(correlation=0.2901502971026189, pvalue=5.378867017564394e-162)
# similarity_c132: KendalltauResult(correlation=0.2892552222519845, pvalue=5.200504496629679e-161)
# similarity_c133: KendalltauResult(correlation=0.32686557895652546, pvalue=4.958935967806422e-205)
# similarity_c134: KendalltauResult(correlation=0.3339639462261274, pvalue=6.105239251476063e-214)
# similarity_c135: KendalltauResult(correlation=0.2720819666118544, pvalue=1.0802509615931062e-142)
# similarity_c136: KendalltauResult(correlation=0.3452426837892544, pvalue=1.7220523366982662e-228)
# similarity_c137: KendalltauResult(correlation=0.30680848748106737, pvalue=6.889973074932518e-181)
# similarity_c138: KendalltauResult(correlation=0.29468128251514975, pvalue=4.96719364271323e-167)
# similarity_c139: KendalltauResult(correlation=0.2974713738247012, pvalue=3.6075297130313046e-170)
# similarity_c140: KendalltauResult(correlation=0.22003283441737578, pvalue=5.319096725279364e-94)
# similarity_c142: KendalltauResult(correlation=0.3033420585476934, pvalue=7.1818709784852475e-177)
# similarity_c143: KendalltauResult(correlation=0.3264871582578401, pvalue=1.4622090922866182e-204)
# similarity_c144: KendalltauResult(correlation=0.2639280465746108, pvalue=2.1850907412294383e-134)
# similarity_c145: KendalltauResult(correlation=0.29917360493117395, pvalue=4.24306432954006e-172)
# similarity_c146: KendalltauResult(correlation=0.2953825127531615, pvalue=8.128128468670892e-168)
# similarity_c147: KendalltauResult(correlation=0.29347769813759556, pvalue=1.099147527806224e-165)
# similarity_c148: KendalltauResult(correlation=0.34896280553532294, pvalue=2.1443376886382277e-233)
# similarity_c149: KendalltauResult(correlation=0.28572603215304826, pvalue=3.7291857324539854e-157)
# similarity_c150: KendalltauResult(correlation=0.31434274031402565, pvalue=8.871839805983296e-190)
# similarity_c151: KendalltauResult(correlation=0.2763825629356125, pvalue=3.558565559871805e-147)
# similarity_c153: KendalltauResult(correlation=0.28230488659229513, pvalue=1.8369276632505101e-153)
# similarity_c154: KendalltauResult(correlation=0.31701763707919073, pvalue=5.494861013243041e-193)
# similarity_c156: KendalltauResult(correlation=0.33559229393516615, pvalue=5.186906825224642e-216)
# similarity_c157: KendalltauResult(correlation=0.3144409866955598, pvalue=6.771184093389901e-190)
# similarity_c160: KendalltauResult(correlation=0.35577808552228346, pvalue=1.6205132239623113e-242)
# similarity_c161: KendalltauResult(correlation=0.3311844475183586, pvalue=1.9824873975161106e-210)
# similarity_c163: KendalltauResult(correlation=0.3322299373143067, pvalue=9.545893742309453e-212)
# similarity_c164: KendalltauResult(correlation=0.3657364552732024, pvalue=3.6695470775553076e-256)
# similarity_c165: KendalltauResult(correlation=0.3058752792640155, pvalue=8.402361650770717e-180)
# similarity_c166: KendalltauResult(correlation=0.313709832357512, pvalue=5.047834100292602e-189)
# similarity_c167: KendalltauResult(correlation=0.3708709541723001, pvalue=2.411947881305558e-263)
# similarity_c168: KendalltauResult(correlation=0.30462005595277075, pvalue=2.399831040401107e-178)
# similarity_c169: KendalltauResult(correlation=0.2616720872099498, pvalue=3.917437341328291e-132)
# similarity_c170: KendalltauResult(correlation=0.34562004522776146, pvalue=5.506929647973554e-229)
# similarity_c171: KendalltauResult(correlation=0.2689494694496786, pvalue=1.795658395567382e-139)
# similarity_c172: KendalltauResult(correlation=0.3021029889541673, pvalue=1.9117163664485697e-175)
# similarity_c174: KendalltauResult(correlation=0.2996510664565271, pvalue=1.2147598273448332e-172)
# similarity_c175: KendalltauResult(correlation=0.32064560318975016, pvalue=2.2157791516367493e-197)
# similarity_c178: KendalltauResult(correlation=0.2625841102234364, pvalue=4.833725260114589e-133)
# similarity_c18: KendalltauResult(correlation=0.20112318653002387, pvalue=7.506588055680926e-79)
# similarity_c180: KendalltauResult(correlation=0.35204737117443224, pvalue=1.677619778682882e-237)
# similarity_c181: KendalltauResult(correlation=0.33753921414281823, pvalue=1.681847877024106e-218)
# similarity_c182: KendalltauResult(correlation=0.3472555429430035, pvalue=3.879080646550949e-231)
# similarity_c184: KendalltauResult(correlation=0.2581113841207101, pvalue=1.290155669925887e-128)
# similarity_c186: KendalltauResult(correlation=0.3555614668158282, pvalue=3.1789737797179814e-242)
# similarity_c187: KendalltauResult(correlation=0.249753821314195, pvalue=1.5081968545948432e-120)
# similarity_c191: KendalltauResult(correlation=0.28833181219158155, pvalue=5.363045847649623e-160)
# similarity_c192: KendalltauResult(correlation=0.36897832104878414, pvalue=1.1001574333908595e-260)
# similarity_c193: KendalltauResult(correlation=0.24964524714592276, pvalue=1.912172441213768e-120)
# similarity_c194: KendalltauResult(correlation=0.32150492800936814, pvalue=1.9831136866964644e-198)
# similarity_c195: KendalltauResult(correlation=0.3035184253673746, pvalue=4.4968279056743535e-177)
# similarity_c198: KendalltauResult(correlation=0.3140191363295655, pvalue=2.159133022218583e-189)
# similarity_c199: KendalltauResult(correlation=0.2178184510147117, pvalue=3.714322623575535e-92)
# similarity_c2: KendalltauResult(correlation=0.24208927947931008, pvalue=2.2115461617834262e-113)
# similarity_c201: KendalltauResult(correlation=0.1848484483361075, pvalue=6.770041389622487e-67)
# similarity_c21: KendalltauResult(correlation=0.2085300633265457, pvalue=1.2665217123114803e-84)
# similarity_c216: KendalltauResult(correlation=0.2263854825214788, pvalue=2.150823354939276e-99)
# similarity_c217: KendalltauResult(correlation=0.25871092538160845, pvalue=3.32440984398351e-129)
# similarity_c218: KendalltauResult(correlation=0.21579367518395712, pvalue=1.736909003391015e-90)
# similarity_c224: KendalltauResult(correlation=0.20322396427856904, pvalue=1.816414993837578e-80)
# similarity_c227: KendalltauResult(correlation=0.23495066032293402, pvalue=6.593007922903709e-107)
# similarity_c237: KendalltauResult(correlation=0.26475718247914815, pvalue=3.2090753885539976e-135)
# similarity_c25: KendalltauResult(correlation=0.23083490490028327, pvalue=2.9118427160403765e-103)
# similarity_c250: KendalltauResult(correlation=0.21612495880470964, pvalue=9.281513367364304e-91)
# similarity_c254: KendalltauResult(correlation=0.26551773128714284, pvalue=5.49432307630582e-136)
# similarity_c258: KendalltauResult(correlation=0.12266325549580592, pvalue=1.951553817400549e-30)
# similarity_c263: KendalltauResult(correlation=0.18397349942886015, pvalue=2.785684957532957e-66)
# similarity_c27: KendalltauResult(correlation=0.21674303711872758, pvalue=2.875679022497099e-91)
# similarity_c278: KendalltauResult(correlation=0.17720959356054553, pvalue=1.2487283391821358e-61)
# similarity_c28: KendalltauResult(correlation=0.23040855267853136, pvalue=6.88805328950503e-103)
# similarity_c280: KendalltauResult(correlation=0.11322710101277192, pvalue=3.532048071287143e-26)
# similarity_c286: KendalltauResult(correlation=0.16561625572447372, pvalue=4.643674551127677e-54)
# similarity_c29: KendalltauResult(correlation=0.2680191741981169, pvalue=1.5979128741665682e-138)
# similarity_c290: KendalltauResult(correlation=0.20510812332065886, pvalue=6.243602180873209e-82)
# similarity_c293: KendalltauResult(correlation=0.2184974367889799, pvalue=1.0149002248707188e-92)
# similarity_c296: KendalltauResult(correlation=0.19284586268201234, pvalue=1.205171386161354e-72)
# similarity_c301: KendalltauResult(correlation=0.24265148181892454, pvalue=6.708211382454434e-114)
# similarity_c307: KendalltauResult(correlation=0.17498488237114332, pvalue=3.8778564458638574e-60)
# similarity_c31: KendalltauResult(correlation=0.23629830408473235, pvalue=4.088960893050761e-108)
# similarity_c311: KendalltauResult(correlation=0.20004803744908434, pvalue=4.967577189328653e-78)
# similarity_c317: KendalltauResult(correlation=0.1757793275048425, pvalue=1.1426204308855251e-60)
# similarity_c320: KendalltauResult(correlation=0.26479213806503094, pvalue=2.9593779504939526e-135)
# similarity_c322: KendalltauResult(correlation=0.22357862147842766, pvalue=5.428273915915619e-97)
# similarity_c325: KendalltauResult(correlation=0.20302694188541165, pvalue=2.5793093740230838e-80)
# similarity_c326: KendalltauResult(correlation=0.18791818433272106, pvalue=4.4904678565184205e-69)
# similarity_c328: KendalltauResult(correlation=0.19938997206333686, pvalue=1.5714943648256561e-77)
# similarity_c329: KendalltauResult(correlation=0.1487952040936169, pvalue=5.595337667118344e-44)
# similarity_c33: KendalltauResult(correlation=0.2434077935862061, pvalue=1.3419932024768307e-114)
# similarity_c330: KendalltauResult(correlation=0.18393033457659586, pvalue=2.98651721184361e-66)
# similarity_c331: KendalltauResult(correlation=0.16583340406101815, pvalue=3.386366178029304e-54)
# similarity_c332: KendalltauResult(correlation=0.18340785449366637, pvalue=6.927165146266131e-66)
# similarity_c333: KendalltauResult(correlation=0.20435710785426858, pvalue=2.401597372462428e-81)
# similarity_c336: KendalltauResult(correlation=0.2174315562346002, pvalue=7.765396159568499e-92)
# similarity_c337: KendalltauResult(correlation=0.14823061841860136, pvalue=1.1685548211764364e-43)
# similarity_c338: KendalltauResult(correlation=0.18720980408850596, pvalue=1.4392138462818307e-68)
# similarity_c339: KendalltauResult(correlation=0.13067523466916195, pvalue=2.582461938288364e-34)
# similarity_c34: KendalltauResult(correlation=0.2764281111232779, pvalue=3.1873358197827864e-147)
# similarity_c340: KendalltauResult(correlation=0.1497736956832897, pvalue=1.55126599284932e-44)
# similarity_c341: KendalltauResult(correlation=0.18275323170349825, pvalue=1.9810771084825408e-65)
# similarity_c343: KendalltauResult(correlation=0.35311642950934674, pvalue=6.208660071183915e-239)
# similarity_c344: KendalltauResult(correlation=0.3406563520324091, pvalue=1.62416338393608e-222)
# similarity_c345: KendalltauResult(correlation=0.22806202656862865, pvalue=7.652052452743962e-101)
# similarity_c346: KendalltauResult(correlation=0.1671227885130119, pvalue=5.150206620341798e-55)
# similarity_c347: KendalltauResult(correlation=0.14883757450074753, pvalue=5.293903734802197e-44)
# similarity_c348: KendalltauResult(correlation=0.10282543087724884, pvalue=7.130922694896632e-22)
# similarity_c349: KendalltauResult(correlation=0.18452246101624628, pvalue=1.1476778476514261e-66)
# similarity_c350: KendalltauResult(correlation=0.2312384830282024, pvalue=1.2870012813707526e-103)
# similarity_c351: KendalltauResult(correlation=0.2817922046660146, pvalue=6.510490593062148e-153)
# similarity_c352: KendalltauResult(correlation=0.17624910939390326, pvalue=5.533050692237568e-61)
# similarity_c354: KendalltauResult(correlation=0.1957620059527774, pvalue=8.401558200825212e-75)
# similarity_c355: KendalltauResult(correlation=0.1243840236553983, pvalue=3.0047572123567205e-31)
# similarity_c357: KendalltauResult(correlation=0.13890939366490915, pvalue=1.4926300345743719e-38)
# similarity_c358: KendalltauResult(correlation=0.16903528276487034, pvalue=3.0695790765948846e-56)
# similarity_c36: KendalltauResult(correlation=0.275808179103948, pvalue=1.4255259854313455e-146)
# similarity_c37: KendalltauResult(correlation=0.28821926579764084, pvalue=7.123623025757598e-160)
# similarity_c38: KendalltauResult(correlation=0.3234454926559506, pvalue=8.317763626013387e-201)
# similarity_c39: KendalltauResult(correlation=0.2612091905120477, pvalue=1.1298395234904637e-131)
# similarity_c41: KendalltauResult(correlation=0.29787680565793234, pvalue=1.2549806182660625e-170)
# similarity_c44: KendalltauResult(correlation=0.25808596187643174, pvalue=1.366420011610485e-128)
# similarity_c45: KendalltauResult(correlation=0.2688273897141335, pvalue=2.393250515875238e-139)
# similarity_c46: KendalltauResult(correlation=0.252679762741609, pvalue=2.4213476823521686e-123)
# similarity_c48: KendalltauResult(correlation=0.2752245267457237, pvalue=5.822643902590103e-146)
# similarity_c5: KendalltauResult(correlation=0.2743035000207218, pvalue=5.3321948113563186e-145)
# similarity_c50: KendalltauResult(correlation=0.2589672663447487, pvalue=1.8599275628838775e-129)
# similarity_c51: KendalltauResult(correlation=0.31335312649248104, pvalue=1.3427782520833935e-188)
# similarity_c52: KendalltauResult(correlation=0.2733781671589213, pvalue=5.267758641551351e-144)
# similarity_c53: KendalltauResult(correlation=0.2601025284408048, pvalue=1.4109073650065954e-130)
# similarity_c55: KendalltauResult(correlation=0.24417814055084974, pvalue=2.592374384942134e-115)
# similarity_c57: KendalltauResult(correlation=0.3380050238062105, pvalue=4.247393681628415e-219)
# similarity_c6: KendalltauResult(correlation=0.2605529788316122, pvalue=5.055356463304392e-131)
# similarity_c60: KendalltauResult(correlation=0.280850257552492, pvalue=6.616832699466654e-152)
# similarity_c62: KendalltauResult(correlation=0.38475308843855915, pvalue=2.9057431180266906e-283)
# similarity_c63: KendalltauResult(correlation=0.420290737789279, pvalue=0.0)
# similarity_c64: KendalltauResult(correlation=0.32558837599658175, pvalue=1.89768719567705e-203)
# similarity_c67: KendalltauResult(correlation=0.29134328887839045, pvalue=2.5861296809459612e-163)
# similarity_c69: KendalltauResult(correlation=0.32219450638541897, pvalue=2.845745412629941e-199)
# similarity_c7: KendalltauResult(correlation=0.31733726883798236, pvalue=2.263611774132591e-193)
# similarity_c70: KendalltauResult(correlation=0.33099404550131545, pvalue=3.4410019283204056e-210)
# similarity_c71: KendalltauResult(correlation=0.3649992101891296, pvalue=3.869720040834332e-255)
# similarity_c72: KendalltauResult(correlation=0.36236271160542666, pvalue=1.6961239857885706e-251)
# similarity_c73: KendalltauResult(correlation=0.36299297141149467, pvalue=2.2976348337560555e-252)
# similarity_c74: KendalltauResult(correlation=0.35976355194300763, pvalue=6.221018990386602e-248)
# similarity_c75: KendalltauResult(correlation=0.3987851080200428, pvalue=3.858808834313428e-304)
# similarity_c76: KendalltauResult(correlation=0.33461856901629555, pvalue=9.003622423428487e-215)
# similarity_c78: KendalltauResult(correlation=0.3218200579124021, pvalue=8.170714952514376e-199)
# similarity_c8: KendalltauResult(correlation=0.2577374652777824, pvalue=3.0009031795089127e-128)
# similarity_c80: KendalltauResult(correlation=0.3647079136401066, pvalue=9.802585536170901e-255)
# similarity_c82: KendalltauResult(correlation=0.2757954679818088, pvalue=1.469937138971686e-146)
# similarity_c84: KendalltauResult(correlation=0.36579550902814073, pvalue=3.037911053006388e-256)
# similarity_c85: KendalltauResult(correlation=0.31698585927384276, pvalue=6.001055642056799e-193)
# similarity_c86: KendalltauResult(correlation=0.3460027029671599, pvalue=1.7309006050840232e-229)
# similarity_c87: KendalltauResult(correlation=0.3230003385660345, pvalue=2.9283049057490353e-200)
# similarity_c89: KendalltauResult(correlation=0.36043988956683015, pvalue=7.392975167623206e-249)
# similarity_c9: KendalltauResult(correlation=0.25366805248793073, pvalue=2.7093853605834485e-124)
# similarity_c90: KendalltauResult(correlation=0.3613738922290158, pvalue=3.8771387553261175e-250)
# similarity_c92: KendalltauResult(correlation=0.30404169989543783, pvalue=1.1192706882828869e-177)
# similarity_c94: KendalltauResult(correlation=0.3138568047072463, pvalue=3.3720572529658134e-189)
# similarity_c95: KendalltauResult(correlation=0.27683036517597426, pvalue=1.2037310714057407e-147)
# similarity_c98: KendalltauResult(correlation=0.3077544068202585, pvalue=5.418390713376799e-182)
# similarity_c99: KendalltauResult(correlation=0.2703627873425294, pvalue=6.393137258946642e-141)
# similarity_d1: KendalltauResult(correlation=0.32103090907959425, pvalue=7.514290318216804e-198)
# similarity_d10: KendalltauResult(correlation=0.3029252396675459, pvalue=2.1692762525056303e-176)
# similarity_d103: KendalltauResult(correlation=0.3762342532699031, pvalue=5.933786645996589e-271)
# similarity_d107: KendalltauResult(correlation=0.36858745404300414, pvalue=3.8807703227224786e-260)
# similarity_d108: KendalltauResult(correlation=0.34794512131905436, pvalue=4.767173980268219e-232)
# similarity_d109: KendalltauResult(correlation=0.3534741946345559, pvalue=2.0554498556703196e-239)
# similarity_d110: KendalltauResult(correlation=0.3481781585582728, pvalue=2.3451383195334694e-232)
# similarity_d111: KendalltauResult(correlation=0.3412442414313465, pvalue=2.813493813144069e-223)
# similarity_d112: KendalltauResult(correlation=0.3239957783185595, pvalue=1.7509203357904368e-201)
# similarity_d113: KendalltauResult(correlation=0.3523768937698364, pvalue=6.08848185774392e-238)
# similarity_d114: KendalltauResult(correlation=0.2681701187735197, pvalue=1.1213546949225536e-138)
# similarity_d115: KendalltauResult(correlation=0.27418724621615714, pvalue=7.048164640721638e-145)
# similarity_d116: KendalltauResult(correlation=0.29772135922677184, pvalue=1.881619817031469e-170)
# similarity_d117: KendalltauResult(correlation=0.3566848122348788, pvalue=9.611854031614439e-244)
# similarity_d119: KendalltauResult(correlation=0.30250815597235386, pvalue=6.54693478847847e-176)
# similarity_d120: KendalltauResult(correlation=0.3546420289810937, pvalue=5.525772986080962e-241)
# similarity_d121: KendalltauResult(correlation=0.3259167466518441, pvalue=7.445018832399289e-204)
# similarity_d122: KendalltauResult(correlation=0.3110624763569818, pvalue=6.999667450786149e-186)
# similarity_d124: KendalltauResult(correlation=0.3464070755402128, pvalue=5.0875428597797295e-230)
# similarity_d127: KendalltauResult(correlation=0.3073277897834621, pvalue=1.707494906487585e-181)
# similarity_d129: KendalltauResult(correlation=0.24818717551054023, pvalue=4.585031464570003e-119)
# similarity_d131: KendalltauResult(correlation=0.3047720597883519, pvalue=1.6003238878568008e-178)
# similarity_d133: KendalltauResult(correlation=0.3086171742354558, pvalue=5.292300319015197e-183)
# similarity_d134: KendalltauResult(correlation=0.30107630102638344, pvalue=2.87024022785425e-174)
# similarity_d135: KendalltauResult(correlation=0.43558269089707996, pvalue=0.0)
# similarity_d144: KendalltauResult(correlation=0.4157435986590296, pvalue=0.0)
# similarity_d159: KendalltauResult(correlation=0.39004700599448583, pvalue=4.728094814058349e-291)
# similarity_d160: KendalltauResult(correlation=0.3677101218003557, pvalue=6.540836571985276e-259)
# similarity_d168: KendalltauResult(correlation=0.37656235911012087, pvalue=2.0151171705063567e-271)
# similarity_d174: KendalltauResult(correlation=0.3918530445984285, pvalue=9.846367300691969e-294)
# similarity_d179: KendalltauResult(correlation=0.3905710749676827, pvalue=7.904587957643838e-292)
# similarity_d188: KendalltauResult(correlation=0.4395020100123921, pvalue=0.0)
# similarity_d189: KendalltauResult(correlation=0.33860535951224247, pvalue=7.188518816204564e-220)
# similarity_d191: KendalltauResult(correlation=0.4765075291551434, pvalue=0.0)
# similarity_d194: KendalltauResult(correlation=0.38701434410411156, pvalue=1.4106898975273993e-286)
# similarity_d2: KendalltauResult(correlation=0.3253127035351882, pvalue=4.1596213901941674e-203)
# similarity_d201: KendalltauResult(correlation=0.3945046376396718, pvalue=1.0816033281781412e-297)
# similarity_d208: KendalltauResult(correlation=0.333341895686441, pvalue=3.750768845572261e-213)
# similarity_d212: KendalltauResult(correlation=0.31947485587772223, pvalue=5.875768103954543e-196)
# similarity_d22: KendalltauResult(correlation=0.29225319337152056, pvalue=2.5336371554904548e-164)
# similarity_d23: KendalltauResult(correlation=0.3333246827085442, pvalue=3.9438103493222734e-213)
# similarity_d242: KendalltauResult(correlation=0.38046255508649457, pvalue=4.984862711880617e-277)
# similarity_d243: KendalltauResult(correlation=0.34317871533190397, pvalue=8.60265675742534e-226)
# similarity_d247: KendalltauResult(correlation=0.32156980769528687, pvalue=1.6523256826258836e-198)
# similarity_d251: KendalltauResult(correlation=0.3504206123556609, pvalue=2.4828758370186477e-235)
# similarity_d253: KendalltauResult(correlation=0.3209888034875082, pvalue=8.457396262844856e-198)
# similarity_d255: KendalltauResult(correlation=0.300743693330408, pvalue=6.889709013767624e-174)
# similarity_d262: KendalltauResult(correlation=0.323566777946362, pvalue=5.9013148889650096e-201)
# similarity_d263: KendalltauResult(correlation=0.34146377310329207, pvalue=1.4608022957426024e-223)
# similarity_d31: KendalltauResult(correlation=0.3519335007052687, pvalue=2.3819622733454321e-237)
# similarity_d38: KendalltauResult(correlation=0.29246398614699537, pvalue=1.4776408126866912e-164)
# similarity_d46: KendalltauResult(correlation=0.2992625827861482, pvalue=3.361386985709612e-172)
# similarity_d47: KendalltauResult(correlation=0.32740527201735176, pvalue=1.058495400519911e-205)
# similarity_d48: KendalltauResult(correlation=0.4240521706823, pvalue=0.0)
# similarity_d51: KendalltauResult(correlation=0.2816476156516814, pvalue=9.298489130062003e-153)
# similarity_d52: KendalltauResult(correlation=0.28051420726093723, pvalue=1.5104560303390056e-151)
# similarity_d54: KendalltauResult(correlation=0.4267855915723142, pvalue=0.0)
# similarity_d57: KendalltauResult(correlation=0.3816899728180598, pvalue=8.342026942818061e-279)
# similarity_d58: KendalltauResult(correlation=0.29938625141196074, pvalue=2.4314581080626922e-172)
# similarity_d59: KendalltauResult(correlation=0.31702558153052773, pvalue=5.375122648614578e-193)
# similarity_d63: KendalltauResult(correlation=0.4183970454055848, pvalue=0.0)
# similarity_d69: KendalltauResult(correlation=0.36144989414680634, pvalue=3.049188407588982e-250)
# similarity_d74: KendalltauResult(correlation=0.3874438741063982, pvalue=3.2943709181280246e-287)
# similarity_d76: KendalltauResult(correlation=0.3822656807249471, pvalue=1.2192972753643898e-279)
# similarity_d79: KendalltauResult(correlation=0.35603575056064657, pvalue=7.266683903256759e-243)
# similarity_d84: KendalltauResult(correlation=0.37574672877285636, pvalue=2.947818528241998e-270)
# similarity_d85: KendalltauResult(correlation=0.3557052613850277, pvalue=2.0326001569869505e-242)
# similarity_d86: KendalltauResult(correlation=0.4233006255858206, pvalue=0.0)
# similarity_d89: KendalltauResult(correlation=0.3510262443625843, pvalue=3.873938540918629e-236)
# similarity_e1: KendalltauResult(correlation=0.14710012299334746, pvalue=5.063224437039907e-43)
# similarity_e100: KendalltauResult(correlation=0.3443182144686731, pvalue=2.797456443384653e-227)
# similarity_e101: KendalltauResult(correlation=0.34038385735155036, pvalue=3.6567642417506666e-222)
# similarity_e102: KendalltauResult(correlation=0.35758094634569143, pvalue=5.851016781468651e-245)
# similarity_e104: KendalltauResult(correlation=0.22325086683894654, pvalue=1.030168637899081e-96)
# similarity_e105: KendalltauResult(correlation=0.21014517028335608, pvalue=6.550023357535664e-86)
# similarity_e106: KendalltauResult(correlation=0.37602981605549785, pvalue=1.1624417830322985e-270)
# similarity_e108: KendalltauResult(correlation=0.3942647152092946, pvalue=2.4740222965438314e-297)
# similarity_e109: KendalltauResult(correlation=0.28620269923326774, pvalue=1.1314149160922326e-157)
# similarity_e112: KendalltauResult(correlation=0.3527573403089147, pvalue=1.8809519572266088e-238)
# similarity_e113: KendalltauResult(correlation=0.3056181438557415, pvalue=1.671504313785273e-179)
# similarity_e114: KendalltauResult(correlation=0.3081121719454677, pvalue=2.066811050667951e-182)
# similarity_e115: KendalltauResult(correlation=0.2652425884558383, pvalue=1.0409996477139788e-135)
# similarity_e116: KendalltauResult(correlation=0.3267172825315683, pvalue=7.576862337281583e-205)
# similarity_e117: KendalltauResult(correlation=0.23063099731596712, pvalue=4.3963190574339494e-103)
# similarity_e118: KendalltauResult(correlation=0.11246761146495551, pvalue=7.518633625327733e-26)
# similarity_e119: KendalltauResult(correlation=0.1971861812624554, pvalue=7.234191997840853e-76)
# similarity_e12: KendalltauResult(correlation=0.2232540446194813, pvalue=1.0237878015280605e-96)
# similarity_e120: KendalltauResult(correlation=0.28142172841866625, pvalue=1.622151134106371e-152)
# similarity_e129: KendalltauResult(correlation=0.10289878464459372, pvalue=6.671281923283137e-22)
# similarity_e135: KendalltauResult(correlation=0.2022150189587711, pvalue=1.0902567237804387e-79)
# similarity_e142: KendalltauResult(correlation=0.11149282728590665, pvalue=1.9682583413852529e-25)
# similarity_e143: KendalltauResult(correlation=0.09088597977792875, pvalue=1.9671821719202772e-17)
# similarity_e15: KendalltauResult(correlation=0.19311226661684613, pvalue=7.679980450669311e-73)
# similarity_e153: KendalltauResult(correlation=0.10049002699921789, pvalue=5.8056014053130015e-21)
# similarity_e16: KendalltauResult(correlation=0.19583138749445378, pvalue=7.458569524339339e-75)
# similarity_e161: KendalltauResult(correlation=0.25149021356141676, pvalue=3.342260455322402e-122)
# similarity_e162: KendalltauResult(correlation=0.20574367942761818, pvalue=1.9890658755227492e-82)
# similarity_e163: KendalltauResult(correlation=0.13883868804800992, pvalue=1.6271690458292675e-38)
# similarity_e166: KendalltauResult(correlation=0.2890905072942642, pvalue=7.889387515554036e-161)
# similarity_e167: KendalltauResult(correlation=0.28706652590864334, pvalue=1.2963163887695942e-158)
# similarity_e168: KendalltauResult(correlation=0.251742317483844, pvalue=1.918176810266835e-122)
# similarity_e17: KendalltauResult(correlation=0.3531879295713797, pvalue=4.978397339432688e-239)
# similarity_e171: KendalltauResult(correlation=0.18366075286122727, pvalue=4.611294567685926e-66)
# similarity_e172: KendalltauResult(correlation=0.2713449863428261, pvalue=6.231616507622997e-142)
# similarity_e18: KendalltauResult(correlation=0.21044494091380525, pvalue=3.7705165397929536e-86)
# similarity_e19: KendalltauResult(correlation=0.28270263878923385, pvalue=6.871831358532416e-154)
# similarity_e20: KendalltauResult(correlation=0.16535144067990734, pvalue=6.821025714362499e-54)
# similarity_e22: KendalltauResult(correlation=0.30541503071655907, pvalue=2.87660678504649e-179)
# similarity_e23: KendalltauResult(correlation=0.30843842408037353, pvalue=8.573874635536827e-183)
# similarity_e24: KendalltauResult(correlation=0.197148577526127, pvalue=7.719834616796353e-76)
# similarity_e26: KendalltauResult(correlation=0.38208984353535497, pvalue=2.1944444079683673e-279)
# similarity_e27: KendalltauResult(correlation=0.1932520889603772, pvalue=6.06101389793736e-73)
# similarity_e28: KendalltauResult(correlation=0.27942290446227913, pvalue=2.1889057483163649e-150)
# similarity_e3: KendalltauResult(correlation=0.17774293106030223, pvalue=5.444714430322386e-62)
# similarity_e30: KendalltauResult(correlation=0.19848589350118723, pvalue=7.599645320600751e-77)
# similarity_e33: KendalltauResult(correlation=0.21078205046553825, pvalue=2.0243155241491833e-86)
# similarity_e36: KendalltauResult(correlation=0.21027413521005991, pvalue=5.165372295870594e-86)
# similarity_e37: KendalltauResult(correlation=0.22227926044043245, pvalue=6.857141255194478e-96)
# similarity_e39: KendalltauResult(correlation=0.21173061795517506, pvalue=3.498582063151664e-87)
# similarity_e40: KendalltauResult(correlation=0.3035631791099063, pvalue=3.992927504586743e-177)
# similarity_e41: KendalltauResult(correlation=0.36525740485758185, pvalue=1.6967586260132195e-255)
# similarity_e42: KendalltauResult(correlation=0.312928098345952, pvalue=4.3018735427020566e-188)
# similarity_e43: KendalltauResult(correlation=0.31564642477842597, pvalue=2.4426819867317663e-191)
# similarity_e44: KendalltauResult(correlation=0.29645210071816513, pvalue=5.0971820836449504e-169)
# similarity_e45: KendalltauResult(correlation=0.27293943772616036, pvalue=1.3977455578419978e-143)
# similarity_e49: KendalltauResult(correlation=0.18904682605266296, pvalue=6.957286309806429e-70)
# similarity_e50: KendalltauResult(correlation=0.23387762976235102, pvalue=5.964666479684041e-106)
# similarity_e51: KendalltauResult(correlation=0.291082181244448, pvalue=5.0302335627016433e-163)
# similarity_e52: KendalltauResult(correlation=0.29965768683264127, pvalue=1.1938578147759853e-172)
# similarity_e53: KendalltauResult(correlation=0.27386496630691987, pvalue=1.5265709955027826e-144)
# similarity_e54: KendalltauResult(correlation=0.27681368182816657, pvalue=1.2533755575288216e-147)
# similarity_e55: KendalltauResult(correlation=0.2097574810581109, pvalue=1.3363579227622959e-85)
# similarity_e56: KendalltauResult(correlation=0.3317180498331599, pvalue=4.220365886846023e-211)
# similarity_e58: KendalltauResult(correlation=0.1982586821929493, pvalue=1.1280525711005783e-76)
# similarity_e59: KendalltauResult(correlation=0.2420561775987393, pvalue=2.372265215174605e-113)
# similarity_e6: KendalltauResult(correlation=0.21691251874725007, pvalue=2.0842487753528716e-91)
# similarity_e60: KendalltauResult(correlation=0.29948211445809375, pvalue=1.8914690413902098e-172)
# similarity_e61: KendalltauResult(correlation=0.2535457079373411, pvalue=3.554862533590376e-124)
# similarity_e62: KendalltauResult(correlation=0.3684629909720579, pvalue=5.79594192792707e-260)
# similarity_e65: KendalltauResult(correlation=0.2851712446346817, pvalue=1.4907850238678947e-156)
# similarity_e66: KendalltauResult(correlation=0.22586326725359393, pvalue=6.049452283257794e-99)
# similarity_e67: KendalltauResult(correlation=0.22481459967711104, pvalue=4.791415705956232e-98)
# similarity_e68: KendalltauResult(correlation=0.35483587359371627, pvalue=3.028368593717308e-241)
# similarity_e7: KendalltauResult(correlation=0.29334873321089167, pvalue=1.5305310700802935e-165)
# similarity_e71: KendalltauResult(correlation=0.2553385057890555, pvalue=6.557211083998669e-126)
# similarity_e72: KendalltauResult(correlation=0.245651041828728, pvalue=1.101980247981866e-116)
# similarity_e73: KendalltauResult(correlation=0.1608249571231341, pvalue=4.4380741819707616e-51)
# similarity_e74: KendalltauResult(correlation=0.21390263095070852, pvalue=6.100501302277701e-89)
# similarity_e75: KendalltauResult(correlation=0.31012238294877115, pvalue=9.003693865622301e-185)
# similarity_e76: KendalltauResult(correlation=0.2716762699635787, pvalue=2.836222533132675e-142)
# similarity_e77: KendalltauResult(correlation=0.25286539808785, pvalue=1.6057330026481027e-123)
# similarity_e78: KendalltauResult(correlation=0.26477995657298087, pvalue=3.0441109485540437e-135)
# similarity_e79: KendalltauResult(correlation=0.17585188682705366, pvalue=1.0216764702049888e-60)
# similarity_e80: KendalltauResult(correlation=0.28981530607124245, pvalue=1.2584197086641219e-161)
# similarity_e81: KendalltauResult(correlation=0.19584595232190496, pvalue=7.274435099141272e-75)
# similarity_e83: KendalltauResult(correlation=0.3079408366116333, pvalue=3.2795643248408294e-182)
# similarity_e84: KendalltauResult(correlation=0.3255150222292369, pvalue=2.3385361779119503e-203)
# similarity_e88: KendalltauResult(correlation=0.2672289661051308, pvalue=1.0170762815555316e-137)
# similarity_e89: KendalltauResult(correlation=0.32917397170001067, pvalue=6.5904034787972515e-208)
# similarity_e90: KendalltauResult(correlation=0.20102229199804408, pvalue=8.966959162274792e-79)
# similarity_e91: KendalltauResult(correlation=0.23951792539657046, pvalue=5.000699636638429e-111)
# similarity_e93: KendalltauResult(correlation=0.3177559414234418, pvalue=7.074855996658564e-194)
# similarity_e94: KendalltauResult(correlation=0.3249197180090517, pvalue=1.2718198090232006e-202)
# similarity_e95: KendalltauResult(correlation=0.2993340828481812, pvalue=2.787446877907929e-172)
# similarity_e96: KendalltauResult(correlation=0.18175991047132975, pvalue=9.688637295130675e-65)
# similarity_e97: KendalltauResult(correlation=0.27965223429087366, pvalue=1.2491090917002897e-150)
# similarity_e98: KendalltauResult(correlation=0.37594798820672687, pvalue=1.5213115898957292e-270)
# similarity_e99: KendalltauResult(correlation=0.16880754182654326, pvalue=4.301772282964996e-56)
# similarity_f1: KendalltauResult(correlation=0.3141557808925618, pvalue=1.4832822598478678e-189)
# similarity_f10: KendalltauResult(correlation=0.3329592379470426, pvalue=1.1439075085554176e-212)
# similarity_f100: KendalltauResult(correlation=0.22378870619446087, pvalue=3.594712817313113e-97)
# similarity_f101: KendalltauResult(correlation=0.23369993886744697, pvalue=8.58142738834684e-106)
# similarity_f103: KendalltauResult(correlation=0.24371577348303683, pvalue=6.958990313520071e-115)
# similarity_f104: KendalltauResult(correlation=0.26746014963903725, pvalue=5.921588731886775e-138)
# similarity_f105: KendalltauResult(correlation=0.2506732591489295, pvalue=2.013025150807209e-121)
# similarity_f106: KendalltauResult(correlation=0.28123291529189043, pvalue=2.581998241351508e-152)
# similarity_f107: KendalltauResult(correlation=0.26866082105110123, pvalue=3.541023589008458e-139)
# similarity_f108: KendalltauResult(correlation=0.28735411504704245, pvalue=6.29261575027184e-159)
# similarity_f109: KendalltauResult(correlation=0.2144407351212674, pvalue=2.223003501231904e-89)
# similarity_f110: KendalltauResult(correlation=0.26106089408709054, pvalue=1.5856896935192884e-131)
# similarity_f112: KendalltauResult(correlation=0.2343701857452445, pvalue=2.1730099258485084e-106)
# similarity_f113: KendalltauResult(correlation=0.2249891127914803, pvalue=3.397725713547438e-98)
# similarity_f114: KendalltauResult(correlation=0.25263289047872073, pvalue=2.6858254916802562e-123)
# ...
# similarity_g4: KendalltauResult(correlation=0.33560712357766187, pvalue=4.965959563282123e-216)
# similarity_g5: KendalltauResult(correlation=0.3432894080205327, pvalue=6.170417793811763e-226)
# similarity_g7: KendalltauResult(correlation=0.3277529741708674, pvalue=3.908408019735726e-206)
# similarity_g8: KendalltauResult(correlation=0.2683973300817577, pvalue=6.57741997789634e-139)
# similarity_h100: KendalltauResult(correlation=0.2976763406691956, pvalue=2.1157062381098e-170)
# similarity_h126: KendalltauResult(correlation=0.2772585711030381, pvalue=4.262590568397047e-148)
# similarity_h127: KendalltauResult(correlation=0.2556448967956188, pvalue=3.3047668550517284e-126)
# similarity_h128: KendalltauResult(correlation=0.26500637343608513, pvalue=1.80090869629905e-135)
# similarity_h132: KendalltauResult(correlation=0.31554102839068854, pvalue=3.267656333160477e-191)
# similarity_h133: KendalltauResult(correlation=0.24958884154143013, pvalue=2.1629926558250616e-120)
# similarity_h135: KendalltauResult(correlation=0.3198275895170846, pvalue=2.1913648793260724e-196)
# similarity_h139: KendalltauResult(correlation=0.12902623138664704, pvalue=1.698393790338738e-33)
# similarity_h14: KendalltauResult(correlation=0.20469474703609072, pvalue=1.3113923112206227e-81)
# similarity_h140: KendalltauResult(correlation=0.20349222191871477, pvalue=1.1262357080458533e-80)
# similarity_h141: KendalltauResult(correlation=0.2138295419984082, pvalue=6.99569515656351e-89)
# similarity_h144: KendalltauResult(correlation=0.14789244960669007, pvalue=1.81399639531963e-43)
# similarity_h148: KendalltauResult(correlation=0.16194485994660535, pvalue=9.085516817364907e-52)
# similarity_h149: KendalltauResult(correlation=0.22617336567078114, pvalue=3.274554902273422e-99)
# similarity_h15: KendalltauResult(correlation=0.1640268358269863, pvalue=4.625353121104588e-53)
# similarity_h16: KendalltauResult(correlation=0.1486580299005315, pvalue=6.693334398056823e-44)
# similarity_h300: KendalltauResult(correlation=0.2734640363294464, pvalue=3.9876715199088046e-144)
# similarity_h301: KendalltauResult(correlation=0.2609160402577127, pvalue=2.207608360929162e-131)
# similarity_h302: KendalltauResult(correlation=0.36088795662223644, pvalue=1.7990063658796215e-249)
# similarity_h303: KendalltauResult(correlation=0.3125406739357514, pvalue=1.24158800337244e-187)
# similarity_h304: KendalltauResult(correlation=0.24578715676163512, pvalue=8.222666432663935e-117)
# similarity_h305: KendalltauResult(correlation=0.315485152416285, pvalue=3.8125377488365587e-191)
# similarity_h306: KendalltauResult(correlation=0.25457160141999124, pvalue=3.630831844813696e-125)
# similarity_i1: KendalltauResult(correlation=0.23380507044013984, pvalue=6.920036135334332e-106)
# similarity_i11: KendalltauResult(correlation=0.2433707194799668, pvalue=1.4523071702257796e-114)
# similarity_i12: KendalltauResult(correlation=0.2726338411647307, pvalue=2.8990711606239253e-143)
# similarity_i13: KendalltauResult(correlation=0.22663176051292558, pvalue=1.3196064785558588e-99)
# similarity_i14: KendalltauResult(correlation=0.3090694783315752, pvalue=1.5592234153533769e-183)
# similarity_i15: KendalltauResult(correlation=0.32616858575922675, pvalue=3.6302609666561314e-204)
# similarity_i16: KendalltauResult(correlation=0.2154949638136862, pvalue=3.0536564094375504e-90)
# similarity_i17: KendalltauResult(correlation=0.28085793718878443, pvalue=6.4931202001143794e-152)
# similarity_i18: KendalltauResult(correlation=0.314751085112747, pvalue=2.8842423404760806e-190)
# similarity_i19: KendalltauResult(correlation=0.25607575087312834, pvalue=1.2591505750643948e-126)
# similarity_i20: KendalltauResult(correlation=0.22862926039408982, pvalue=2.46138307336014e-101)
# similarity_i21: KendalltauResult(correlation=0.29914156231078143, pvalue=4.614262606611584e-172)
# similarity_i22: KendalltauResult(correlation=0.2539053267678622, pvalue=1.5993875369435091e-124)
# similarity_i23: KendalltauResult(correlation=0.2299252652221977, pvalue=1.8244303543626124e-102)
# similarity_i24: KendalltauResult(correlation=0.30315695283154154, pvalue=1.1735919075751633e-176)
# similarity_i25: KendalltauResult(correlation=0.32702234946290876, pvalue=3.1672103303905514e-205)
# similarity_i26: KendalltauResult(correlation=0.2495308470466701, pvalue=2.4551515213618538e-120)
# similarity_i27: KendalltauResult(correlation=0.24316151559475938, pvalue=2.267550596337722e-114)
# similarity_i28: KendalltauResult(correlation=0.37159919554485765, pvalue=2.267746181662977e-264)
# similarity_i29: KendalltauResult(correlation=0.2966244953121779, pvalue=3.258977826270732e-169)
# similarity_i3: KendalltauResult(correlation=0.22206740840477934, pvalue=1.0355452902966251e-95)
# similarity_i30: KendalltauResult(correlation=0.293324105411747, pvalue=1.630396072205933e-165)
# similarity_i31: KendalltauResult(correlation=0.30964968809422017, pvalue=3.243035189340817e-184)
# similarity_i32: KendalltauResult(correlation=0.35658683066838925, pvalue=1.3047617577016484e-243)
# similarity_i33: KendalltauResult(correlation=0.3275985869998852, pvalue=6.083866042483626e-206)
# similarity_i34: KendalltauResult(correlation=0.27277710610384115, pvalue=2.0595453511911295e-143)
# similarity_i35: KendalltauResult(correlation=0.38212294541592584, pvalue=1.9646651995852765e-279)
# similarity_i36: KendalltauResult(correlation=0.37756494886884917, pvalue=7.388489323554872e-273)
# similarity_i37: KendalltauResult(correlation=0.40260956689367056, pvalue=5.8472386060164e-310)
# similarity_i38: KendalltauResult(correlation=0.3556112520442067, pvalue=2.722995170425296e-242)
# similarity_i39: KendalltauResult(correlation=0.3881882691966743, pvalue=2.6388925522744953e-288)
# similarity_i4: KendalltauResult(correlation=0.198550773187106, pvalue=6.788529975006412e-77)
# similarity_i42: KendalltauResult(correlation=0.38514633877974025, pvalue=7.733023676391785e-284)
# similarity_i43: KendalltauResult(correlation=0.36669826351506757, pvalue=1.6858676031929006e-257)
# similarity_i44: KendalltauResult(correlation=0.35029217705904625, pvalue=3.680216732842392e-235)
# similarity_i45: KendalltauResult(correlation=0.36414703537571497, pvalue=5.856870330732187e-254)
# similarity_i46: KendalltauResult(correlation=0.35020213994389365, pvalue=4.849033528987495e-235)
# similarity_i5: KendalltauResult(correlation=0.2159133715841011, pvalue=1.3851322472237698e-90)
# similarity_i6: KendalltauResult(correlation=0.21058661696264827, pvalue=2.9035519179031316e-86)
# similarity_i7: KendalltauResult(correlation=0.23050626942997637, pvalue=5.655300100814132e-103)
# similarity_i8: KendalltauResult(correlation=0.17721568430657056, pvalue=1.2369643677658395e-61)
# similarity_j1: KendalltauResult(correlation=0.3358274496947411, pvalue=2.6003194695995122e-216)
# similarity_j101: KendalltauResult(correlation=0.2527449072425723, pvalue=2.096390959836973e-123)
# similarity_j102: KendalltauResult(correlation=0.26628251713585055, pvalue=9.267628003036645e-137)
# similarity_j103: KendalltauResult(correlation=0.29283764017487857, pvalue=5.676131470880313e-165)
# similarity_j104: KendalltauResult(correlation=0.22592046730322027, pvalue=5.402237746433307e-99)
# similarity_j106: KendalltauResult(correlation=0.2563405659176947, pvalue=6.95281560138518e-127)
# similarity_j107: KendalltauResult(correlation=0.325505224072588, pvalue=2.4046967216945226e-203)
# similarity_j108: KendalltauResult(correlation=0.27716615065248446, pvalue=5.333857881535514e-148)
# similarity_j109: KendalltauResult(correlation=0.2841445567068978, pvalue=1.923222247829253e-155)
# similarity_j11: KendalltauResult(correlation=0.3649724638696284, pvalue=4.2146002486662193e-255)
# similarity_j110: KendalltauResult(correlation=0.3362733982297909, pvalue=7.0106183668822984e-217)
# similarity_j111: KendalltauResult(correlation=0.3037448422304789, pvalue=2.4643363145424123e-177)
# similarity_j112: KendalltauResult(correlation=0.3373225954363629, pvalue=3.1874430921992334e-218)
# similarity_j113: KendalltauResult(correlation=0.3236321872623699, pvalue=4.9038658896504165e-201)
# similarity_j114: KendalltauResult(correlation=0.25360555613741304, pvalue=3.1126509145729266e-124)
# similarity_j115: KendalltauResult(correlation=0.29608533188144076, pvalue=1.3189212857672472e-168)
# similarity_j116: KendalltauResult(correlation=0.29835400236824094, pvalue=3.6148866398178724e-171)
# similarity_j117: KendalltauResult(correlation=0.276003612606838, pvalue=8.892980575621142e-147)
# similarity_j118: KendalltauResult(correlation=0.31380834355409065, pvalue=3.8519086351372446e-189)
# similarity_j12: KendalltauResult(correlation=0.34650187932616755, pvalue=3.8172278686051085e-230)
# similarity_j121: KendalltauResult(correlation=0.29794221497394024, pvalue=1.0582687295692586e-170)
# similarity_j122: KendalltauResult(correlation=0.31283170566972984, pvalue=5.6006721599303235e-188)
# similarity_j123: KendalltauResult(correlation=0.32170777633350595, pvalue=1.1207555378907089e-198)
# similarity_j13: KendalltauResult(correlation=0.32153538173949325, pvalue=1.8203282121410086e-198)
# similarity_j15: KendalltauResult(correlation=0.37405376619294345, pvalue=7.585716267905172e-268)
# similarity_j16: KendalltauResult(correlation=0.35080247564992567, pvalue=7.698599811700406e-236)
# similarity_j17: KendalltauResult(correlation=0.37700804283012607, pvalue=4.640189606649255e-272)
# similarity_j19: KendalltauResult(correlation=0.37787637136125923, pvalue=2.641262707331781e-273)
# similarity_j2: KendalltauResult(correlation=0.32582326694111213, pvalue=9.718261937655624e-204)
# similarity_j20: KendalltauResult(correlation=0.37419385335151906, pvalue=4.7967635357386435e-268)
# similarity_j21: KendalltauResult(correlation=0.32989691677167693, pvalue=8.201627561465073e-209)
# similarity_j24: KendalltauResult(correlation=0.3587855899834239, pvalue=1.3439256303558486e-246)
# similarity_j25: KendalltauResult(correlation=0.3723189628359891, pvalue=2.181689680546648e-265)
# similarity_j26: KendalltauResult(correlation=0.36488428045978777, pvalue=5.584452786618868e-255)
# similarity_j27: KendalltauResult(correlation=0.354379862086973, pvalue=1.245682822895654e-240)
# similarity_j28: KendalltauResult(correlation=0.33343140317150444, pvalue=2.8891123987216152e-213)
# similarity_j29: KendalltauResult(correlation=0.35647269538418114, pvalue=1.862476961179985e-243)
# similarity_j3: KendalltauResult(correlation=0.2973884867157519, pvalue=4.4759432062618266e-170)
# similarity_j31: KendalltauResult(correlation=0.33111347708641486, pvalue=2.4349396357536662e-210)
# similarity_j32: KendalltauResult(correlation=0.3213568963994555, pvalue=3.0068497861555566e-198)
# similarity_j33: KendalltauResult(correlation=0.35600609127565513, pvalue=7.969719795734518e-243)
# similarity_j35: KendalltauResult(correlation=0.31569382667140333, pvalue=2.1429828903962564e-191)
# similarity_j36: KendalltauResult(correlation=0.2591958017282095, pvalue=1.1077098484832538e-129)
# similarity_j37: KendalltauResult(correlation=0.24462276501067667, pvalue=1.0012485061281632e-115)
# similarity_j38: KendalltauResult(correlation=0.13949569417357913, pvalue=7.285043119481397e-39)
# similarity_j39: KendalltauResult(correlation=0.3315869663860996, pvalue=6.17302007702066e-211)
# similarity_j40: KendalltauResult(correlation=0.3368006449835226, pvalue=1.4850225516162152e-217)
# similarity_j41: KendalltauResult(correlation=0.37951186907650125, pvalue=1.1738393993683967e-275)
# similarity_j42: KendalltauResult(correlation=0.39117750141973967, pvalue=9.947116562244665e-293)
# similarity_j43: KendalltauResult(correlation=0.36211457990866797, pvalue=3.722573967104529e-251)
# similarity_j44: KendalltauResult(correlation=0.370505774225843, pvalue=7.879363676127433e-263)
# similarity_j45: KendalltauResult(correlation=0.34493496870746826, pvalue=4.359135923031599e-228)
# similarity_j46: KendalltauResult(correlation=0.36189637231194527, pvalue=7.427896559452911e-251)
# similarity_j47: KendalltauResult(correlation=0.3063143426079065, pvalue=2.592841570476882e-180)
# similarity_j51: KendalltauResult(correlation=0.3615592627602123, pvalue=2.1578269248197496e-250)
# similarity_j52: KendalltauResult(correlation=0.32783188905414823, pvalue=3.1169689075697916e-206)
# similarity_j53: KendalltauResult(correlation=0.30981837527760897, pvalue=2.0532587857012279e-184)
# similarity_j54: KendalltauResult(correlation=0.30221341682775144, pvalue=1.427725745006783e-175)
# similarity_j55: KendalltauResult(correlation=0.3312543586901242, pvalue=1.6189987248394157e-210)
# similarity_j56: KendalltauResult(correlation=0.3216855318697624, pvalue=1.1931537889490775e-198)
# similarity_j57: KendalltauResult(correlation=0.3570762088707479, pvalue=2.833122015784243e-244)
# similarity_j58: KendalltauResult(correlation=0.30085465083408136, pvalue=5.14500360982792e-174)
# similarity_j59: KendalltauResult(correlation=0.33055551178751347, pvalue=1.2238254897165664e-209)
# similarity_j6: KendalltauResult(correlation=0.3338731146658412, pvalue=7.960100622743297e-214)
# similarity_j60: KendalltauResult(correlation=0.3324131893251467, pvalue=5.603750904874023e-212)
# similarity_j65: KendalltauResult(correlation=0.27026745392648555, pvalue=8.010493886033313e-141)
# similarity_j66: KendalltauResult(correlation=0.2607444401088337, pvalue=3.266306773934118e-131)
# similarity_j67: KendalltauResult(correlation=0.31293869094773463, pvalue=4.178919518839374e-188)
# similarity_j68: KendalltauResult(correlation=0.26577725003081787, pvalue=3.0052109298531046e-136)
# similarity_j69: KendalltauResult(correlation=0.24913177077450854, pvalue=5.866285246571493e-120)
# similarity_j7: KendalltauResult(correlation=0.3362045463182036, pvalue=8.584156806500067e-217)
# similarity_j70: KendalltauResult(correlation=0.24080942836892072, pvalue=3.3087147347881647e-112)
# similarity_j71: KendalltauResult(correlation=0.3056954698487549, pvalue=1.3592729443071704e-179)
# similarity_j72: KendalltauResult(correlation=0.25701955169196294, pvalue=1.5123343553235535e-127)
# similarity_j73: KendalltauResult(correlation=0.2531312723925947, pvalue=8.911638896301725e-124)
# similarity_j74: KendalltauResult(correlation=0.27044911704705804, pvalue=5.211820376917075e-141)
# similarity_j75: KendalltauResult(correlation=0.257404857581807, pvalue=6.352038023858479e-128)
# similarity_j8: KendalltauResult(correlation=0.2724328465459049, pvalue=4.682194587491354e-143)
# similarity_j80: KendalltauResult(correlation=0.3781787901421541, pvalue=9.719225762598338e-274)
# similarity_j81: KendalltauResult(correlation=0.3095898398941481, pvalue=3.813765625827458e-184)
# similarity_j82: KendalltauResult(correlation=0.30630375000612386, pvalue=2.6674952251179526e-180)
# similarity_j83: KendalltauResult(correlation=0.2955093591595088, pvalue=5.855839992466524e-168)
# similarity_j86: KendalltauResult(correlation=0.30024954845724716, pvalue=2.5258103278226033e-173)
# similarity_j89: KendalltauResult(correlation=0.3037710589198909, pvalue=2.298489300847943e-177)
# similarity_j92: KendalltauResult(correlation=0.2698487813410261, pvalue=2.1547384369898246e-140)
# similarity_j93: KendalltauResult(correlation=0.26796753526442646, pvalue=1.803651051633363e-138)
# similarity_j95: KendalltauResult(correlation=0.2648882659262085, pvalue=2.3682796145012514e-135)
# similarity_j97: KendalltauResult(correlation=0.2801606791764411, pvalue=3.595400960167292e-151)
# similarity_j98: KendalltauResult(correlation=0.29072362167410515, pvalue=1.2529791982958105e-162)
# similarity_j99: KendalltauResult(correlation=0.28676304786757023, pvalue=2.7771053522588554e-158)
#
# Cumulative Correlations
# Long_tailed_Duck_Clangula_hyemalis: 0.22416742862932987
# Velvet_Scoter_Melanitta_fusca: 0.2124458204542276
# Aquatic_Warbler_Acrocephalus_paludicola: 0.27361276706949406
# Atlantic_Puffin_Fratercula_arctica: 0.346769803594072
# Balearic_Shearwater_Puffinus_mauretanicus: 0.25513075704914334
# Black_legged_Kittiwake_Rissa_tridactyla: 0.25560926782290844
# Great_Bustard_Otis_tarda: 0.29778000722112635
# Horned_Grebe_Podiceps_auritus: 0.24364932793424576
# Leach's_Storm_Petrel_Hydrobates_leucorhous: 0.29314427661977593
# European_Turtle_Dove_Streptopelia_turtur: 0.3115092311067228
#
# Owner of the audio: Atlantic_Puffin_Fratercula_arctica
